# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from statistics import mean
import math
from math import log
import numpy as np
import matplotlib.pyplot as plt

from pylab import rcParams
rcParams['figure.figsize'] = 10, 5

# %%
df = pd.read_csv("../waveform/Cosmic.dat",
                 delim_whitespace=True,)
                 #usecols=[1,])
                 #names=["y",])
#df
s1=df.to_numpy()
s2=np.transpose(s1)
s = s2.ravel()
print(s)
t=df.index.to_numpy() +1 #this is not necessaryplt.hist(s, bins = 250, log=True, histtype='step' )


plt.hist(s, bins = 250, log=True, histtype='bar' , color='C0')
plt.ylim((1,10000000))
plt.grid()
plt.show()
# Out:
# [43690  1012     0 ...  1538  1534  1530]

# %%
from scipy import signal
a=signal.detrend(s).max() < 0.0001

plt.hist(s-a, bins = 250, log=True, histtype='bar' , color='C1')
plt.title('noise remove')
plt.ylim((1,10000000))
plt.grid()
plt.show() #yazmanssan matrisi gorursun

# %%
signsq = (1 + 1) / 12.0
bs = 1 / np.sqrt(2 * 3.14 * signsq) * np.exp(-s ** 2 / 2 / signsq)
plt.hist(s-bs, bins = 250, log=True, histtype='bar' , color='C2')
plt.title('baseline')
plt.ylim((1,10000000))
plt.grid()
plt.show()

# %%
signsq = (1 + 1) / 12.0
bs = 1 / np.sqrt(2 * 3.14 * signsq) * np.exp(-s ** 2 / 2 / signsq)
plt.hist(s-bs, bins = 250, log=True, histtype='bar' , color='C2')
plt.title('baseline')
plt.ylim((1,10000000))
plt.grid()
plt.show()
decwelch

# %%
Fs = 1 / t  # sampling frequency
print(Fs)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 15))

# plot time signal:
axes[0, 0].set_title("Signal")
axes[0, 0].plot(t, s, color='C0',linestyle='dashed')
axes[0, 0].set_xlabel("Time")
axes[0, 0].set_ylabel("Amplitude")

# plot different spectrum types:
axes[1, 0].set_title("Magnitude Spectrum")
axes[1, 0].magnitude_spectrum(s, Fs=Fs, color='C1')

axes[1, 1].set_title("Log. Magnitude Spectrum")
axes[1, 1].magnitude_spectrum(s, Fs=Fs, scale='dB', color='C1')

axes[2, 0].set_title("Phase Spectrum ")
axes[2, 0].phase_spectrum(s, Fs=Fs, color='C2')

axes[2, 1].set_title("Angle Spectrum")
axes[2, 1].angle_spectrum(s, Fs=Fs, color='C2')

axes[0, 1].remove()  # don't display empty ax

fig.tight_layout()
plt.show()

# %%
Fs = 1 / t  # sampling frequency



s_mean = [np.mean(s)]*len(t)

# plot time signal:

plt.plot(t, s, color='C0' ,linestyle='dotted')
plt.show()


from scipy.fftpack import fft, ifft
y = fft(a)
yinv = ifft(y)
yinv

from scipy.fftpack import fft
N = 500
T = 1.0/800.0
x = np.linspace(0.0, N*T,N)
y = np.sin(50.0 * 2.0 * np.pi *x) + 0.5 * np.sin(80.0 * 2.0 * np.pi * x)
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N*np.abs(yf[0:N//2]))
plt.grid()
plt.show()

# %%
n, bins, patches = plt.hist(s, 50, density=True, facecolor='g', alpha=1)

plt.xlabel('time')
plt.ylabel('amp')
plt.title('probabiliyt')
plt.yscale('log')

plt.grid(True)
plt.show()

# %%
Fs = 1 / t  # sampling frequency
print(Fs)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 15))

# plot time signal:
axes[0, 0].set_title("Signal")
axes[0, 0].plot(t, s, color='C0',linestyle='dashed')
axes[0, 0].set_xlabel("Time")
axes[0, 0].set_ylabel("Amplitude")

# plot different spectrum types:
axes[1, 0].set_title("Magnitude Spectrum")
axes[1, 0].magnitude_spectrum(s, Fs=Fs, color='C1')

axes[1, 1].set_title("Log. Magnitude Spectrum")
axes[1, 1].magnitude_spectrum(s, Fs=Fs, scale='dB', color='C1')

axes[2, 0].set_title("Phase Spectrum ")
axes[2, 0].phase_spectrum(s, Fs=Fs, color='C2')

axes[2, 1].set_title("Angle Spectrum")
axes[2, 1].angle_spectrum(s, Fs=Fs, color='C2')

axes[0, 1].remove()  # don't display empty ax

fig.tight_layout()
plt.show()
# Out:
# [1.00000000e+00 5.00000000e-01 3.33333333e-01 ... 2.04923870e-07
#  2.04923828e-07 2.04923786e-07]

# %%
from scipy.fftpack import fft, ifft
y = fft(s)
yinv = ifft(y)
yinv

from scipy.fftpack import fft
N = 500
T = 1.0/800.0
x = np.linspace(0.0, N*T,N)
y = np.sin(50.0 * 2.0 * np.pi *x) + 0.5 * np.sin(80.0 * 2.0 * np.pi * x)
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N*np.abs(yf[0:N//2]))
plt.grid()
plt.show()
