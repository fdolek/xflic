# %% [markdown]
# test

# %%
import uproot
file = uproot.open("../root/Run_440.root")
file
# Out:
# <ROOTDirectory b'Run_440.root' at 0x7f8d9375c4a8>

# %%
file.keys()
file.values()
# Out:
# [<TTree b'T' at 0x7f8d9375c518>, <TTree b'T' at 0x7f8d9375c898>]

# %%
file["T"].keys()
# Out:
# [b'TPCWF', b'PMTWF']

# %%
file["T"].values()
# Out:
# [<TBranchElement b'TPCWF' at 0x7f8d937a5208>,
#  <TBranchElement b'PMTWF' at 0x7f8d9375cd30>]

# %%
events = uproot.open("../root/Run_440.root")["T"]
events.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-15eeef1ff909> in <module>
# ----> 1 events = uproot.open("../root/Run_440.roo")["T"]
#       2 events.show()
#
# ~/anaconda3/lib/python3.7/site-packages/uproot/rootio.py in open(path, localsource, xrootdsource, httpsource, **options)
#      51         else:
#      52             openfcn = localsource
# ---> 53         return ROOTDirectory.read(openfcn(path), **options)
#      54
#      55     elif _bytesid(parsed.scheme) == b"root":
#
# ~/anaconda3/lib/python3.7/site-packages/uproot/rootio.py in <lambda>(path)
#      48                 if n in options:
#      49                     kwargs[n] = options.pop(n)
# ---> 50             openfcn = lambda path: MemmapSource(path, **kwargs)
#      51         else:
#      52             openfcn = localsource
#
# ...

# %%
a = events.array("PMTWF")
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e84f8ca66c5c> in <module>
# ----> 1 a = events.array("PMTWF")
#       2 a
#
# NameError: name 'events' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys


# Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, "Int16")


# If Stereo
if spf.getnchannels() == 2:
    print("Just mono files")
    sys.exit(0)

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()

# %%
events["PMTWF"].interpretation
#Standard Template Library(STL)
# Out:
# asgenobj(STLVector(STLVector(asdtype('>i4'))))

# %%
b = events.array("TPCWF")
b
# Out:
# <ObjectArray [[] [] [] ... [] [] []] at 0x7f18f8540da0>

# %%
events["TPCWF"].interpretation
# Out:
# asgenobj(STLVector(STLVector(asdtype('>i4'))))

# %%
len(events.array("PMTWF", entrystart=100, entrystop=300))
# 200
# Out:
# 200

# %%
events.array("PMTWF", entrystart=-10)
# Out:
# <ObjectArray [[[903, 902, 902, 902, 903, 903, 904, 903, 903, 902, 902, 903, 903, 904, 903, 905, 904, 903, 904, 903, 902, 902, 902, 902, 902, 903, 904, 904, 903, 904, 904, 904, 902, 901, 901, 902, 903, 903, 903, 904, 903, 904, 902, 903, 902, 903, 902, 903, 904, 903, 902, 902, 902, 903, 902, 902, 902, 903, 903, 903, 904, 903, 902, 903, 904, 903, 904, 902, 903, 902, 903, 903, 902, 902, 902, 903, 903, 904, 904, 902, 904, 902, 903, 903, 903, 904, 903, 903, 903, 904, 903, 902, 904, 902, 902, 903, 903, 904, 903, 903, 903, 903, 903, 903, 903, 903, 903, 904, 902, 903, 903, 905, 903, 903, 903, 904, 903, 903, 902, 902, 903, 903, 903, 902, 904, 902, 902, 902, 903, 902, 903, 904, 903, 902, 901, 902, 903, 903, 903, 903, 903, 903, 902, 903, 902, 902, 902, 903, 904, 904, 902, 903, 903, 903, 905, 903, 903, 903, 903, 903, 903, 903, 902, 904, 904, 902, 904, 903, 902, 903, 903, 904, 903, 903, 903, 903, 902, 904, 903, 904, 903, 903, 904, 904, 902, 902, 902, 902, 902, 904, 903, 902, 903, 902, 904, 902, 90
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open("wavfile.wav", "r")

# Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, "Int16")


# If Stereo
if spf.getnchannels() == 2:
    print("Just mono files")
    sys.exit(0)

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()

# %%
import numpy
histogram = None

for data in events.iterate(["PMTWF"], namedecode="utf-8"):
    # operate on a batch of data in the loop


    # accumulate results
    counts, edges = numpy.histogram(data, bins=120, range=(0, 60000))
    if histogram is None:
        histogram = counts, edges
    else:
        histogram = histogram[0] + counts, edges
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-03367123ade7> in <module>
#       7
#       8     # accumulate results
# ----> 9     counts, edges = numpy.histogram(data, bins=120, range=(0, 60000))
#      10     if histogram is None:
#      11         histogram = counts, edges
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     822
#     823             # Only include values in the right range
# --> 824             keep = (tmp_a >= first_edge)
#     825             keep &= (tmp_a <= last_edge)
#     826             if not np.logical_and.reduce(keep):
#
# TypeError: '>=' not supported between instances of 'dict' and 'int'

# %%
import matplotlib.pyplot

counts, edges = histogram

matplotlib.pyplot.step(x=edges, y=numpy.append(counts, 0), where="post");
matplotlib.pyplot.xlim(edges[0], edges[-1]);
matplotlib.pyplot.ylim(0, counts.max() * 1.1);
matplotlib.pyplot.xlabel("mass");
matplotlib.pyplot.ylabel("events per bin");
