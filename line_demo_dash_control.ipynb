# %%
# %matplotlib inline

# %% [markdown]
# # A simple plot with a custom dashed line
#
#
# A Line object's ``set_dashes`` method allows you to specify dashes with
# a series of on/off lengths (in points).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd



df = pd.read_csv("../waveform/waveforms_ch0_run454.txt",
                 delim_whitespace=True,
                 usecols=[1,])
                 #names=["y",])
sig=df.to_numpy()
s= -1*(sig-903.4) 
s

dashes = [1, 10]  # 10 points on, 5 off, 100 on, 5 off

fig, ax = plt.subplots()
line1, = ax.plot(s, '-', linewidth=1, label='test')
line1.set_dashes(dashes)


ax.legend(loc='lower right')
plt.show()
